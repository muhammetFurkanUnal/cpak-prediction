# %%
from lib.kneeap_inference import *

# %%
shuffle = 3

onnx_path = f"/Users/furkan/projects/cpak-prediction/notebooks/out/models/kneeap-sh{shuffle}-ep1000.onnx"
input_folder_path = f"/Users/furkan/projects/cpak-prediction/kneeap-furkan-2026-04-29/labeled-data/video"
output_path = f"./out/inference/kneeap-sh{shuffle}-ep1000"

# %%
infer_images(
	onnx_path=onnx_path,
	input_folder=input_folder_path,
	output_folder=output_path,
	landmarks=False
)
# Out:
# /Users/furkan/projects/cpak-prediction/.venv/lib/python3.11/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CoreMLExecutionProvider, AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Processed: 4000.r.png
# Processed: 4001.l.png
# Processed: 4001.r.png
# Processed: 4002.l.png
# Processed: 4002.r.png
# Processed: 4003.l.png
# Processed: 4003.r.png
# Processed: 4004.r.png
# Processed: 4005.l.png
# Processed: 4005.r.png
# Processed: 4006.l.png
# Processed: 4006.r.png
# Processed: 4007.l.png
# Processed: 4007.r.png
# Processed: 4008.r.png
# Processed: 4009.l.png
# Processed: 4009.r.png
# Processed: 4010.r.png
# Processed: 4011.l.png
# Processed: 4011.r.png
# Processed: 4012.l.png
# Processed: 4013.l.png
# Processed: 4014.l.png
# Processed: 4014.r.png
# Processed: 4015.l.png
# Processed: 4015.r.png
# Processed: 4016.l.png
# ...
