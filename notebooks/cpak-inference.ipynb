# %%
from lib.cpak_inference import *
import cv2

# %%
onnx_path = "/Users/furkan/projects/cpak-prediction/notebooks/out/models/sh14-ep1000.onnx"
input_folder_path = "/Users/furkan/projects/cpak-prediction/preprocessing/long-id-split-prepped"
output_path = "./out/inference/sh14-ep1000"

# %%
# session = ort.InferenceSession(onnx_path, providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
# img = cv2.imread(input_path)
# heatmap, offset = get_predictions(session, img)

# %%
# coords = extract_coordinates(heatmap, offset, debug=False)
# metrics:OrthopedicMetrics = compute_orthopedic_metrics(coords)
# metrics

# %%
# lined = draw_lines(img, metrics, coords)
# cv2.imwrite("lined.jpg", lined)

# %%
infer_images(
	onnx_path=onnx_path,
	input_folder=input_folder_path,
	output_folder=output_path,
	landmarks=False
)
# Out:
# Processed: 10105873454.l.png
# Processed: 10105873454.r.png
# Processed: 10178557442.l.png
# Processed: 10178557442.r.png
# Processed: 10373685384.l.png
# Processed: 10373685384.r.png
# Processed: 11682274.l.png
# Processed: 11682274.r.png
# Processed: 15461812840.l.png
# Processed: 15461812840.r.png
# Processed: 16153402226.l.png
# Processed: 16153402226.r.png
# Processed: 16414661324.l.png
# Processed: 16414661324.r.png
# Processed: 17005366222.l.png
# Processed: 17005366222.r.png
# Processed: 17825593662.l.png
# Processed: 17825593662.r.png
# Processed: 18491512988.l.png
# Processed: 18491512988.r.png
# Processed: 18697770342.l.png
# Processed: 18697770342.r.png
# Processed: 19328686216.l.png
# Processed: 19328686216.r.png
# Processed: 21041015778.l.png
# Processed: 21041015778.r.png
# Processed: 21764680352.l.png
# Processed: 21764680352.r.png
# Processed: 22016794742.l.png
# Processed: 22016794742.r.png
# Processed: 22166429754.l.png
# Processed: 22166429754.r.png
# ...
