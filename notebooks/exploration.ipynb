# %%
from lib.inference import infer_single_image, infer_images

# %% [markdown]
# ### Fill fields and run all

# %%
onnx_path = "/home/furkan/projects/cpak/training/deeplabcut/cpak-furkan-2026-02-20/notebooks/out/models/sh10-ep290.onnx"
input_path = "/home/furkan/projects/cpak/training/deeplabcut/cpak-furkan-2026-02-20/labeled-data/video"
output_path = "./out/inference/yiyoruz"

# %%
infer_images (
	onnx_path=onnx_path,
	input_folder=input_path,
	output_folder=output_path
)
# Out:
# 🚀 GPU (CUDA) aktif!
# 2026-03-12 12:16:40.196285486 [E:onnxruntime:Default, provider_bridge_ort.cc:2251 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1844 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.12: cannot open shared object file: No such file or directory
#
# 2026-03-12 12:16:40.196299161 [W:onnxruntime:Default, onnxruntime_pybind_state.cc:1013 CreateExecutionProviderFactoryInstance] Failed to create CUDAExecutionProvider. Require cuDNN 9.* and CUDA 12.*. Please install all dependencies as mentioned in the GPU requirements page (https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html#requirements), make sure they're in the PATH, and that your GPU is supported.
# Processed: 4000.l.png
# Processed: 4000.r.png
# Processed: 4001.l.png
# Processed: 4001.r.png
# Processed: 4002.l.png
# ...
