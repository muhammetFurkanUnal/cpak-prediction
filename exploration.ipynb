# %%
import pandas as pd
path = "/home/furkan/projects/cpak/cpak-furkan-2026-04-13/labeled-data/video/CollectedData_furkan.h5"
h5 = pd.read_hdf(path)
h5.head()
# Out:
# scorer                             furkan                                      \
# bodyparts                               1                       2
# coords                                  x           y           x           y
# labeled-data video 4000.l.png  367.785861  308.539572  324.133515  277.303893
#                    4000.r.png  334.575993  295.706751  376.670151  261.026905
#                    4001.l.png  306.768781  275.376376  264.277021  246.576406
#                    4001.r.png  283.872499  282.175964  313.983259  241.710459
#                    4002.l.png  393.104160  415.110027  361.772713  378.755981
#
# scorer                                                                         \
# bodyparts                               3                       4
# coords                                  x           y           x           y
# labeled-data video 4000.l.png  399.603570  301.167188  339.654349  250.530467
# ...

# %%
csv_path = "/home/furkan/projects/cpak/cpak-furkan-2026-04-13/labeled-data/video/CollectedData_furkan.csv"
csv = pd.read_csv(csv_path)
csv.head()
# Out:
#          scorer Unnamed: 1  Unnamed: 2             furkan            furkan.1  \
# 0     bodyparts        NaN         NaN                  1                   1
# 1        coords        NaN         NaN                  x                   y
# 2  labeled-data      video  4000.l.png  367.7858605792452   308.5395718813882
# 3  labeled-data      video  4000.r.png  334.5759932703861  295.70675087199413
# 4  labeled-data      video  4001.l.png  306.7687811799589   275.3763761318664
#
#              furkan.2            furkan.3           furkan.4  \
# 0                   2                   2                  3
# 1                   x                   y                  x
# 2  324.13351501334796  277.30389349867954  399.6035702361658
# 3  376.67015129770414   261.0269047699423  306.8321163887446
# 4   264.2770214804257  246.57640566884942  336.5130129696322
#
#              furkan.5            furkan.6  ...           furkan.92  \
# ...
