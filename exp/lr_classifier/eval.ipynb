# %%
import torch
from shared import ModelCheckpoint
from models import SimpleCNNClassifier

# %% [markdown]
# ## Configurations

# %%
model_pt_path = "/home/furkan/projects/cpak/exp/lr_classifier/out/models/sh1/ep1000.pt"
prediction_csv_path = ""

# %% [markdown]
# ## Eval

# %%
checkpoint:ModelCheckpoint = torch.load(model_pt_path)
